# %%
from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession.builder
    .appName("Reading complex data format")
    .master("local[*]")
    .getOrCreate()
)

spark
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/30 15:02:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://pop-os.lan:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Reading complex data format</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Read Parquet data
df_parquet = spark.read.format('parquet').load('data/input/sales_data.parquet')

# %%
df_parquet.printSchema()
# Out:
# root
#  |-- transacted_at: timestamp (nullable = true)
#  |-- trx_id: integer (nullable = true)
#  |-- retailer_id: integer (nullable = true)
#  |-- description: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- city_id: integer (nullable = true)

# %%
df_parquet.show()
# Out:
# +-------------------+----------+-----------+--------------------+-------+----------+
# |      transacted_at|    trx_id|retailer_id|         description| amount|   city_id|
# +-------------------+----------+-----------+--------------------+-------+----------+
# |2017-11-25 02:00:00|1995601912| 2077350195|Walgreen       11-25| 197.23| 216510442|
# |2017-11-25 02:00:00|1734117021|  644879053|unkn    ppd id: 7...|   8.58| 930259917|
# |2017-11-25 02:00:00|1734117022|  847200066|Wal-Mart  ppd id:...|1737.26|1646415505|
# |2017-11-25 02:00:00|1734117030| 1953761884|Home Depot     pp...|  384.5| 287177635|
# |2017-11-25 02:00:00|1734117089| 1898522855| Target        11-25|  66.33|1855530529|
# |2017-11-25 02:00:00|1734117117|  997626433|Sears  ppd id: 85...| 298.87| 957346984|
# |2017-11-25 02:00:00|1734117123| 1953761884|unkn   ppd id: 15...|  19.55|  45522086|
# |2017-11-25 02:00:00|1734117152| 1429095612|Ikea     arc id: ...|   9.39|1268541279|
# |2017-11-25 02:00:00|1734117153|  847200066|unkn        Kings...|2907.57|1483931123|
# |2017-11-25 02:00:00|1734117212| 1996661856|unkn    ppd id: 4...| 140.38| 336763936|
# |2017-11-25 02:00:00|1734117241|  486576507|              iTunes|2912.67|1663872965|
# |2017-11-25 02:00:00|2076947148|  847200066|Wal-Mart         ...|  62.83|1556600840|
# |2017-11-25 02:00:00|2076947147|  562903918|McDonald's    ccd...|  31.37| 930259917|
# |2017-11-25 02:00:00|2076947146|  511877722|unkn     ccd id: ...|1915.35|1698762556|
# |2017-11-25 02:00:00|2076947113| 1996661856|AutoZone  arc id:...| 1523.6|1759612211|
# |2017-11-25 02:00:00|2076947018|  902350112|DineEquity    arc...|  22.28|2130657559|
# |2017-11-25 02:00:00|2076946994| 1898522855|Target    ppd id:...|2589.93|2074005445|
# |2017-11-25 02:00:00|2076946985|  847200066|Wal-Mart    ppd i...|   42.2| 459344513|
# |2017-11-25 02:00:00|2076946960|  386167994|Wendy's  ppd id: ...|  14.62| 352952442|
# |2017-11-25 02:00:00|2076946954|  486576507|iTunes     ppd id...|  37.42| 485114748|
# +-------------------+----------+-----------+--------------------+-------+----------+
# only showing top 20 rows

# %%
# Read ORC format
df_orc = spark.read.format('orc').load('data/input/sales_data.orc')

# %%
df_orc.printSchema()
# Out:
# root
#  |-- transacted_at: timestamp (nullable = true)
#  |-- trx_id: integer (nullable = true)
#  |-- retailer_id: integer (nullable = true)
#  |-- description: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- city_id: integer (nullable = true)

# %%
df_orc.show()
# Out:
# +-------------------+----------+-----------+--------------------+-------+----------+
# |      transacted_at|    trx_id|retailer_id|         description| amount|   city_id|
# +-------------------+----------+-----------+--------------------+-------+----------+
# |2017-11-24 19:00:00|1995601912| 2077350195|Walgreen       11-25| 197.23| 216510442|
# |2017-11-24 19:00:00|1734117021|  644879053|unkn    ppd id: 7...|   8.58| 930259917|
# |2017-11-24 19:00:00|1734117022|  847200066|Wal-Mart  ppd id:...|1737.26|1646415505|
# |2017-11-24 19:00:00|1734117030| 1953761884|Home Depot     pp...|  384.5| 287177635|
# |2017-11-24 19:00:00|1734117089| 1898522855| Target        11-25|  66.33|1855530529|
# |2017-11-24 19:00:00|1734117117|  997626433|Sears  ppd id: 85...| 298.87| 957346984|
# |2017-11-24 19:00:00|1734117123| 1953761884|unkn   ppd id: 15...|  19.55|  45522086|
# |2017-11-24 19:00:00|1734117152| 1429095612|Ikea     arc id: ...|   9.39|1268541279|
# |2017-11-24 19:00:00|1734117153|  847200066|unkn        Kings...|2907.57|1483931123|
# |2017-11-24 19:00:00|1734117212| 1996661856|unkn    ppd id: 4...| 140.38| 336763936|
# |2017-11-24 19:00:00|1734117241|  486576507|              iTunes|2912.67|1663872965|
# |2017-11-24 19:00:00|2076947148|  847200066|Wal-Mart         ...|  62.83|1556600840|
# |2017-11-24 19:00:00|2076947147|  562903918|McDonald's    ccd...|  31.37| 930259917|
# |2017-11-24 19:00:00|2076947146|  511877722|unkn     ccd id: ...|1915.35|1698762556|
# |2017-11-24 19:00:00|2076947113| 1996661856|AutoZone  arc id:...| 1523.6|1759612211|
# |2017-11-24 19:00:00|2076947018|  902350112|DineEquity    arc...|  22.28|2130657559|
# |2017-11-24 19:00:00|2076946994| 1898522855|Target    ppd id:...|2589.93|2074005445|
# |2017-11-24 19:00:00|2076946985|  847200066|Wal-Mart    ppd i...|   42.2| 459344513|
# |2017-11-24 19:00:00|2076946960|  386167994|Wendy's  ppd id: ...|  14.62| 352952442|
# |2017-11-24 19:00:00|2076946954|  486576507|iTunes     ppd id...|  37.42| 485114748|
# +-------------------+----------+-----------+--------------------+-------+----------+
# only showing top 20 rows
